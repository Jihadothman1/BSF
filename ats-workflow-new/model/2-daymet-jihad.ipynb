# %% [markdown]
# # Download Daymet

# %% [markdown]
# Daymet provides gridded meteorological data for North American at 1km spatial resolution with daily timestep from 1980 ~ present. [website](https://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=1328) and [user guide](https://daac.ornl.gov/DAYMET/guides/Daymet_V3_CFMosaics.html)
#
# Available variables:
#
# | Variable | Description (units) |
# | ---- | ---- |
# | tmax | Daily maximum 2-meter air temperature (°C) |
# | tmin | Daily minimum 2-meter air temperature (°C) |
# | prcp | Daily total precipitation (mm/day) |
# | srad | Incident shortwave radiation flux density (W/m2) |
# | vp   | Water vapor pressure (Pa) |
# | swe  | Snow water equivalent (kg/m2) |
# | dayl | Duration of the daylight period (seconds) |
#
# Notes:
#  - The Daymet calendar is based on a standard calendar year. <span style="color:blue;"> All Daymet years, including leap years, have 365 days. Keep this in mind during post-processing of model results!</span>  For leap years, the Daymet database includes leap day (February 29) and values for December 31 are discarded from leap years to maintain a 365-day year.
#
#  - DayMet's incident shortwave radiation is the "daylit" radiation.  To get the daily average radiation, one must multiply by daylit fraction, given by dayl / 86400.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

# %%
import logging,yaml
import numpy as np
import rasterio
import fiona
import os
import datetime 

import watershed_workflow
import watershed_workflow.ui
import watershed_workflow.sources.manager_daymet
import watershed_workflow.daymet
import watershed_workflow.io

watershed_workflow.ui.setup_logging(1,None)

# %%
watershed_shapefile = '../../data/examples/BSF/sources/shapefile/BSF_USGS_UTM_12.shp'
config_fname = '../../data/examples/BSF/processed/config.yaml'

# %%
# Load the dictionary from the file
with open(config_fname, 'r') as file:
    config = yaml.load(file, Loader=yaml.FullLoader)

# %%
# dates are in YYYY-MM-DD
# start and end of simulation -- one year of simulation that is in both the MODIS and DayMet dataset ranges
start_date = config['start_date']
end_date = config['end_date']
origin_date = config['origin_date']

# %% [markdown]
# ## import watershed

# %%
crs, watershed = watershed_workflow.get_split_form_shapes(watershed_shapefile)
logging.info(f'crs: {crs}')

bounds = watershed.exterior().bounds
print(bounds)
print(bounds[2] - bounds[0], bounds[3] - bounds[1])
# Out:
# 2023-10-20 04:39:52,622 - root - INFO:
# 2023-10-20 04:39:52,624 - root - INFO: Loading shapes
# 2023-10-20 04:39:52,627 - root - INFO: ------------------------------
# 2023-10-20 04:39:52,629 - root - INFO: Loading file: '../../data/examples/BSF/sources/shapefile/BSF_USGS_UTM_12.shp'
# 2023-10-20 04:39:52,769 - root - INFO: ... found 1 shapes
# 2023-10-20 04:39:52,770 - root - INFO: Converting to shapely
# 2023-10-20 04:39:52,786 - root - INFO: crs: epsg:26912
# (429014.0500423278, 4589994.87125261, 466557.2906380118, 4633218.102138742)
# 37543.24059568404 43223.230886131525

# %%
watershed.exterior()

# %% [markdown]
# ## Download

# %% [markdown]
# returned raw data has `dim(nband, ncol, nrow)`

# %%
# setting vars = None to download all available variables
source = watershed_workflow.sources.manager_daymet.FileManagerDaymet()
data = source.get_data(bounds, crs, start = start_date, end = end_date, buffer=0.02)
# Out:
# 2023-10-20 04:39:52,897 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:52,935 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2010_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:52,937 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:52,965 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2011_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:52,966 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:52,997 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2012_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:52,998 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,039 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2013_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,040 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,073 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2014_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,074 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,106 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2015_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,107 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,147 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2016_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,148 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,183 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2017_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,184 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,215 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2018_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,216 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,251 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2019_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,252 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,286 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2020_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,287 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,323 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2021_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,324 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,357 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmin_2022_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,359 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,388 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2010_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,389 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,415 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2011_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,416 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,451 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2012_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,452 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,481 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2013_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,482 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,512 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2014_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,513 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,541 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2015_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,542 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,577 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2016_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,579 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,608 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2017_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,609 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,635 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2018_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,637 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,665 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2019_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,666 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,700 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2020_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,702 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,734 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2021_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,736 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,768 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_tmax_2022_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,770 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,803 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2010_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,805 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,846 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2011_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,847 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,878 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2012_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,879 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,910 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2013_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,912 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,944 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2014_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,945 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:53,978 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2015_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:53,980 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,010 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2016_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,011 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,041 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2017_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,043 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,071 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2018_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,072 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,102 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2019_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,104 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,133 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2020_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,134 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,163 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2021_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,164 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,193 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_prcp_2022_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,195 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,223 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2010_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,224 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,254 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2011_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,255 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,282 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2012_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,284 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,314 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2013_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,315 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,343 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2014_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,345 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,374 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2015_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,375 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,402 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2016_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,403 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,428 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2017_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,430 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,460 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2018_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,461 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,498 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2019_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,502 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,541 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2020_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,542 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,585 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2021_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,587 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,624 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_srad_2022_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,625 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,656 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2010_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,658 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,686 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2011_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,687 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,715 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2012_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,716 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,747 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2013_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,748 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,777 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2014_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,778 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,810 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2015_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,811 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,842 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2016_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,844 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,874 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2017_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,875 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,904 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2018_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,905 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,934 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2019_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,935 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,965 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2020_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,966 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:54,996 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2021_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:54,997 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,028 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_vp_2022_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,029 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,061 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2010_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,062 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,094 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2011_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,095 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,127 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2012_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,129 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,162 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2013_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,163 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,199 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2014_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,202 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,251 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2015_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,253 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,294 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2016_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,296 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,341 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2017_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,343 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,377 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2018_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,378 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,431 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2019_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,433 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,478 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2020_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,479 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,532 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2021_41.8702x-111.8751_41.4384x-111.3804.nc
# 2023-10-20 04:39:55,533 - root - INFO: Collecting DayMet file to tile bounds: [-111.8751, 41.4384, -111.3804, 41.8702]
# 2023-10-20 04:39:55,599 - root - INFO:   Using existing: /home/jovyan/workdir/src/chapters/data/meteorology/daymet/daymet_dayl_2022_41.8702x-111.8751_41.4384x-111.3804.nc

# %% [markdown]
# ## Reproject Daymet CRS
#
# Reproject daymet CRS to the same as the watershed. This is necessary if watershed meshes are using watershed CRS.

# %%
data_new = watershed_workflow.warp.state(data, dst_crs=crs)

# %% [markdown]
# ## plot Daymet

# %%
ivar = 'tmax'
islice = 100
daymet_crs = watershed_workflow.crs.daymet_crs()

fig = plt.figure()
ax1 = watershed_workflow.plot.get_ax(daymet_crs, fig, 1, 2, 1)
ax2 = watershed_workflow.plot.get_ax(crs, fig, 1, 2, 2)

watershed_ext_daymet = watershed_workflow.warp.shply(watershed.exterior(),
                                                     crs, daymet_crs)
watershed_workflow.plot.raster(data[ivar].profile, data[ivar].data[islice,:,:], ax1)
watershed_workflow.plot.shply(watershed_ext_daymet, daymet_crs, ax=ax1, color='r')

watershed_workflow.plot.raster(data_new[ivar].profile, data_new[ivar].data[islice,:,:], ax2)
watershed_workflow.plot.hucs(watershed, crs, ax=ax2, color='r')

ax1.set_title("Raw Daymet")
ax2.set_title("Reprojected Daymet")
# Out:
# /opt/conda/envs/watershed_workflow/lib/python3.10/site-packages/pyproj/crs/crs.py:1282: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# 2023-10-20 04:40:47,970 - root - INFO: BOUNDS: (-943250.0, -51000.0, -898250.0, 0.0)
# 2023-10-20 04:40:47,986 - root - INFO: BOUNDS: (421018.32655323925, 4581445.225162174, 474404.8469870568, 4640991.72872297)
# Text(0.5, 1.0, 'Reprojected Daymet')

# %% [markdown]
# # save daymet

# %% [markdown]
# ## Write data to HDF5

# %% [markdown]
# This will write daymet in a format that ATS can read. E.g., this will calculate mean air temperature, convert units, partition precipitation into rain and snow based on mean temp, and so on.
#
# - dout has dims of `(ntime, nrow, ncol)` or `(ntime, ny, nx)`

# %%
assert(len(data_new.collections) == 1)
met_data = data_new.collections[0]

# %%
met_data_ats = watershed_workflow.daymet.daymet_to_daily_averages(met_data)


config['daymet_filename'] = os.path.join('..', '..', 'data', 'examples','BSF', 'processed','watershed_daymet_raw.h5')
attrs = watershed_workflow.daymet.getAttributes(bounds, start_date, end_date)
attrs['name']="Daymet forcing reformatted for ats modeling"

watershed_workflow.io.write_dataset_to_hdf5(
    filename = config['daymet_filename'],
    dataset= met_data_ats.collections[0],
    attributes= attrs,
    time0 = origin_date
)
# Out:
# 2023-10-20 04:40:48,177 - root - INFO: Converting to ATS met input
# 2023-10-20 04:40:49,201 - root - INFO: Writing HDF5 file: ../../data/examples/BSF/processed/watershed_daymet_raw.h5

# %% [markdown]
# ## Write typical Daymet
#
# This will average days, smooths the forcing and generate a "typical year" data, then looped 10 years. The dataset will be used during cyclic spinup.

# %%
config['daymet_typical_filename'] = os.path.join('..', '..', 'data', 'examples','BSF', 'processed','watershed_daymet_typical.h5')

met_data_typical = watershed_workflow.datasets.State()
ntypical_years = 10
# here we make up some new times. 
# It does not really matter what timeframe you choose as long as the nunmber of days are consistent.
new_times = np.array([datetime.date(1980,10,1) + datetime.timedelta(days=i) for i in range(365*ntypical_years)])

for (ds_key, ds_val) in met_data_ats.items():
    # average and smooth forcing data. Hint: make filter=False if no smoothing is needed.
    smooth_dat = watershed_workflow.utils.compute_average_year(ds_val.data, output_nyears=ntypical_years, filter=True)
    met_data_typical[ds_key] = watershed_workflow.datasets.Dataset(ds_val.profile, new_times, smooth_dat)

attrs = watershed_workflow.daymet.getAttributes(bounds, new_times[0], new_times[-1])
attrs['name']=f"{ntypical_years}-yrs typical Daymet forcing generated using data from {start_date} to {end_date}"

watershed_workflow.io.write_dataset_to_hdf5(config['daymet_typical_filename'], met_data_typical.collections[0], 
                                            attributes=attrs, time0=origin_date)
# Out:
# 2023-10-20 04:41:17,854 - root - INFO: Writing HDF5 file: ../../data/examples/BSF/processed/watershed_daymet_typical.h5

# %%
# after smoothing, the forcing can look quite different!
ivar = 'air temperature [K]'
islice = 100
# daymet_crs = watershed_workflow.crs.daymet_crs()
profile = met_data_ats.collections[0].profile

fig = plt.figure()
ax1 = watershed_workflow.plot.get_ax(crs, fig, 1, 2, 1)
ax2 = watershed_workflow.plot.get_ax(crs, fig, 1, 2, 2)

watershed_workflow.plot.raster(profile, met_data_ats.collections[0].data[ivar][islice,:,:], ax1)
watershed_workflow.plot.hucs(watershed, crs, ax=ax1, color='r')

watershed_workflow.plot.raster(profile, met_data_typical.collections[0].data[ivar][islice,:,:], ax2)
watershed_workflow.plot.hucs(watershed, crs, ax=ax2, color='r')

ax1.set_title("Raw Daymet")
ax2.set_title("Typical Daymet")
# Out:
# 2023-10-20 04:41:37,849 - root - INFO: BOUNDS: (421018.32655323925, 4581445.225162174, 474404.8469870568, 4640991.72872297)
# 2023-10-20 04:41:37,853 - root - INFO: BOUNDS: (421018.32655323925, 4581445.225162174, 474404.8469870568, 4640991.72872297)
# Text(0.5, 1.0, 'Typical Daymet')

# %% [markdown]
# Get mean precipitation for spinup

# %%
# calculate the basin-averaged, annual-averaged precip rate
precip_total = met_data_typical.collections[0].data['precipitation rain [m s^-1]'] + met_data_typical.collections[0].data['precipitation snow [m SWE s^-1]']
mean_precip = precip_total.mean()
config['mean_precip [m s^-1]'] = float(mean_precip)
logging.info(f'Mean annual precip rate [m s^-1] = {mean_precip}')
# Out:
# 2023-10-20 04:41:38,125 - root - INFO: Mean annual precip rate [m s^-1] = 1.7838124669236027e-08

# %%
with open(config_fname, 'w') as file:
    yaml.dump(config, file)
